# %%
import pandas as pd
import sweetviz

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
report_train = sweetviz.analyze([train, 'Train'], target_feat = "SalePrice")
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:06 left)
# :TARGET::                          |▌                    | [  2%]   00:00  -> (00:36 left)
# :Id:                               |▌                    | [  2%]   00:00  -> (00:36 left)
# :Id:                               |▊                    | [  4%]   00:03  -> (01:18 left)
# :MSSubClass:                       |▊                    | [  4%]   00:03  -> (01:18 left)
# :MSSubClass:                       |█                    | [  5%]   00:05  -> (01:54 left)
# :MSZoning:                         |█                    | [  5%]   00:05  -> (01:54 left)
# :MSZoning:                         |█▎                   | [  6%]   00:06  -> (01:45 left)
# ...

# %%
report.show_html("Report.html")

# %%
compare = sweetviz.compare([train, 'Train'], [test, 'Test'], target_feat="SalePrice")
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |▎                    | [  1%]   00:00  -> (00:18 left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:18 left)
# :TARGET::                          |▌                    | [  2%]   00:01  -> (00:47 left)
# :Id:                               |▌                    | [  2%]   00:01  -> (00:47 left)
# :Id:                               |▊                    | [  4%]   00:03  -> (01:15 left)
# :MSSubClass:                       |▊                    | [  4%]   00:03  -> (01:15 left)
# :MSSubClass:                       |█                    | [  5%]   00:05  -> (01:41 left)
# :MSZoning:                         |█                    | [  5%]   00:05  -> (01:41 left)
# ...

# %%
compare.show_html("Report.html")
